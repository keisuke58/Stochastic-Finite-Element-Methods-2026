# %% [markdown]
# # Stochastic FEM — Notes

# %% [markdown]
# ## Lecture Notes
#
# <!-- 講義メモ -->

# %% [markdown]
# ## Key Formulas
#
# <!-- 重要な公式（LaTeX OK）-->

# %%
# Sandbox — 演習・実験用

# %% [markdown]
# ## Exam Prep Checklist
#
# - [ ] 講義スライド通読
# - [ ] 重要概念の整理
# - [ ] 演習問題を解く
# - [ ] チートシート完成
# - [ ] 最終確認
